# %% [markdown]
# # Command（修改功能提示词，将一些需要用户提供的数据转为让AI自行分析获取）
#
# ## 输出格式（最高优先级）
# ⚠️ **你的最终输出必须是完整的 md格式 提示词文档**。
#
# ## 当前任务
# 上面是我给你提供的一个基于实时数据进行A股市场分析并生成HTML页面的提示词模板，
# 请你将其中需要用户提供的数据，改为让AI自行分析获取，返回对应修改后的完整提示词
#
# ## 具体要求
# - 输出提示词格式、内容仿照提供的提示词模板，并在此基础上加入你的修改
# - 允许你分析当前提示词撰写存在的不足，并着力优化修改
# - 保证AI获取所有数据的实时性、准确性和真实性，不能因为大模型幻觉而胡乱编造数据
# - 提示词涉及到需要用户提供某个具体板块以及板块中具体个股标的相关数据的，AI不需要被指定板块，让AI基于一定的板块、概念分类标准去分析所有板块（比如申万行业、同花顺板块等）、所有概念以及板块、概念中所有对应个股标的，不得遗漏

# %% [markdown]
# # Command（需要整合数据获取Skill，搞定分析数据源）

# %% [markdown]
# # Command（还需要什么功能内容，比如多Agent投资角色等，整合进来，也用HTML输出）

# %% [markdown]
# # Command（将优化后的所有HTML功能页面，通过一个前后端系统架构整合起来）

# %% [markdown]
# # 将这套内容包装成一个完整的AI Skill，用户只要调用skill，就更新当日或者实时的HTML页面
# 我现在有很多类似这样的生成HTML页面的提示词文档，我想整合一些行情数据获取skill（请你自行联网搜索github、clawhub等，类似https://github.com/jwangkun/claude-for-financial-services-cn、https://github.com/BitSoulTech/BitSoulStockSkill、https://github.com/xticktop/skills）、多智能体分析师Agents团队协同skill（请你自行联网搜索github、clawhub等，类似https://github.com/shaohk/TradingAgents-CN-SKILL），打造一个综合skill。这个skill整合了A股数据获取skill主流渠道以及联网搜索，能够基于生成HTML页面的提示词文档获取到想要的数据，具备生成不同分析功能的HTML页面的能力，同时具备多智能体投研功能（也通过HTML页面输出），并且skill能够将所有生成的HTML功能页面，通过一个前后端系统架构整合起来。用户只要调用skill，就更新当日或者实时的HTML页面，得到他想看到的对应功能的最新分析内容。我需要你给出这个skill的完整设计架构，以及对应代码部分的完整代码

# %% [markdown]
# # 参考的Skill
# ## 数据获取
# https://github.com/xticktop/skills
#
# ## 综合类（数据获取+Agent投研分析）
# https://github.com/BitSoulTech/BitSoulStockSkill
#
# ## 多Agents投研
#
#
# ## A股Skill汇总类
# https://github.com/jwangkun/claude-for-financial-services-cn
